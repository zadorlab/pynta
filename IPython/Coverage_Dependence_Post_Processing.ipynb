# %%
from pysidt import *
from pysidt.sidt import *
import numpy as np
from molecule.molecule import *
import os
from pysidt.plotting import *
from pynta.mol import *
from pynta.geometricanalysis import *
from pynta.coveragedependence import get_atom_centered_correction
from pynta.postprocessing import *
from ase.visualize import view
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#ammonia decomp
path = "/Users/mjohns9/Runs/coveragedep/Pt111_ammonia_N_1_8_25"
pynta_path = "/Users/mjohns9/Runs/pynta/Pt111_ammonia_decomp_10_2_24"
rxn_file = "/Users/mjohns9/Runs/pynta/Pt111_ammonia_decomp_10_2_24/ammonia_rxns.yaml"
slab_path = "/Users/mjohns9/Runs/pynta/Pt111_ammonia_decomp_10_2_24/slab.xyz"
ts_dict = {"TS1":"22", "TS2": "37", "TS4": "98","TS7": "25"}
coad_names = ["N#[Pt]"]
coad_nice_names = {"N#[Pt]":"N"}
cmap = plt.colormaps["viridis"]
MLsize = 9 #number of site occupations that constitute one monolayer (for (a,b,c) size slab this is usually a*b)
from ase import units
to_eV = units.J / units.mol #J/mol -> eV (= 1/Faraday constant, provided by ASE)

metal = "Pt"
facet = "fcc111"
slabxyz = os.path.join(pynta_path,"slab.xyz")
slab = read(slabxyz)
nslab = len(slab)

#Site Information (load_or_build_sites lives in pynta.postprocessing)
# custom_surface=True (DEFAULT for covdep): load the EXACT sites the run saved. Required because the
#   SIDT training maps configs onto these exact site indices, so re-deriving with ACAT (which can
#   reorder sites, or fail get_labels on stepped/open surfaces) would silently break that mapping.
# custom_surface=False: rebuild sites + neighbor list with ACAT from metal/facet. Flat surfaces only,
#   and only when ACAT is trusted to reproduce the run's site ordering.
custom_surface = True
# Where the saved sites live. None -> default sites.json / site_adjacency.json in pynta_path (with the
# legacy single_sites_lists.json / neighbor_site_list.json fallback). Set BOTH to point elsewhere / at
# non-standard filenames.
sites_file = None
site_adjacency_file = None
sites, site_adjacency = load_or_build_sites(pynta_path, slab, facet, metal, custom_surface=custom_surface,
                                            sites_file=sites_file, site_adjacency_file=site_adjacency_file)

# %%
#Extract data
Ncoad_energy_dict,Ncoad_config_dict,tree_dict,admol_name_structure_dict,admol_name_path_dict,ts_info,max_coad_indexes,ad_energy_dict,coadmol_E_dict = extract_covdep_data(
                                                                    path,pynta_path,ts_dict,metal,facet,sites,site_adjacency,nslab,coad_names)

# %%
#analyze an individual configuration
# The plotting/sample-overlay body lives in plot_config_energy_correction (pynta.postprocessing);
# it reconstructs the isolated-coadsorbate reference internally so the pair (lowest-coverage) layer
# is drawn instead of dropped. config_name/coad_name/coad_nice_name/reactant_names/forward are left in
# scope for the downstream "...draws parameters from the first individual configuration cell" cells.
config_names = ['N#[Pt]']
coad_name = 'N#[Pt]'
coad_nice_name = coad_nice_names[coad_name]
forward = True
plot_lowest_samples = True        # overlay lowest-energy sample dots per coverage and print their xyz paths
visualize_lowest_samples = False  # if True, open ASE viewer with the 3D structures of those lowest samples
write_lowest_samples = True       # if True, ALWAYS write those lowest structures to a multi-frame xyz

for config_name in config_names:
    if config_name in ts_info:  # ts_info holds the (possibly compound "TSn_index") TS config keys
        reactant_names = ts_info[config_name]['species_names'] if forward else ts_info[config_name]['reverse_names']
    else:
        reactant_names = None
    plot_config_energy_correction(
        config_name, coad_name, Ncoad_energy_dict, ts_dict, ts_info,
        admol_name_structure_dict, coadmol_E_dict, path, pynta_path, slab, metal, facet,
        sites, site_adjacency, ad_energy_dict, MLsize, coad_nice_name,
        reactant_names=reactant_names, cmap=cmap, forward=forward,
        plot_lowest_samples=plot_lowest_samples, visualize_lowest_samples=visualize_lowest_samples,
        write_lowest_samples=write_lowest_samples)

# %%
# Per-config: predicted vs sampled energy (true model-validation plot)
# which tree to validate: default = final (converged) iteration
import matplotlib as mpl
val_iter = max(tree_dict.keys())
tree = tree_dict[val_iter]

for config_name in config_names:
    if config_name in ts_info:  # ts_info holds the (possibly compound "TSn_index") TS config keys
        reactant_names = ts_info[config_name]['species_names'] if forward else ts_info[config_name]['reverse_names']
    else:
        reactant_names = None

    # model-free sampled data for this config (admol_name_structure_dict lets it keep the pair layer)
    _3D, _Es, _Ecorr, _xyzs, _mols = analyze_covdep_sample_data(
        config_name, coad_name, Ncoad_energy_dict, path, pynta_path, slab, metal, facet,
        sites, site_adjacency, ad_energy_dict, ts_dict, coadmol_E_dict, reactant_names=reactant_names,
        admol_name_structure_dict=admol_name_structure_dict)

    # _Es holds None placeholders; valid entries align 1:1 with _mols
    sampled = np.array([E for E in _Es if E is not None])      # eV, atom-corr-subtracted
    mols = _mols
    if len(mols) == 0:
        print(f"{config_name}: no valid samples")
        continue

    # tree prediction for the SAME configs, same frame
    pred = np.array([tree.evaluate(m, estimate_uncertainty=False) for m in mols]) * to_eV

    # put both on the physical association-energy (dE) axis by adding atom_corr back
    ac = np.array([get_atom_centered_correction(m, coadmol_E_dict[coad_name]) for m in mols])  # eV
    sampled_dE = sampled + ac
    pred_dE = pred + ac

    # color by coverage (number of coadsorbates)
    ncoad = np.array([len(split_adsorbed_structures(m)) - 1 for m in mols])

    resid = pred_dE - sampled_dE
    mae = np.mean(np.abs(resid))
    rmse = np.sqrt(np.mean(resid**2))
    mx = np.max(np.abs(resid))

    plt.figure(figsize=(5, 5))
    # N_coad is discrete (integer coverage): one distinct viridis color per level, integer ticks
    nc_lo, nc_hi = int(ncoad.min()), int(ncoad.max())
    n_levels = nc_hi - nc_lo + 1
    disc_cmap = plt.get_cmap('viridis', n_levels)
    norm = mpl.colors.BoundaryNorm(np.arange(nc_lo, nc_hi + 2) - 0.5, n_levels)
    sc = plt.scatter(sampled_dE, pred_dE, c=ncoad, cmap=disc_cmap, norm=norm, s=30, zorder=3)
    plt.colorbar(sc, ticks=np.arange(nc_lo, nc_hi + 1), label=r"$N_{coad}$")
    lo = min(sampled_dE.min(), pred_dE.min())
    hi = max(sampled_dE.max(), pred_dE.max())
    pad = 0.05 * (hi - lo + 1e-9)
    plt.plot([lo - pad, hi + pad], [lo - pad, hi + pad], 'k--', lw=1, zorder=1)
    plt.xlabel("Sampled $dE$ [eV]")
    plt.ylabel(f"Predicted $dE$ (iter {val_iter}) [eV]")
    title = config_name if config_name not in ts_info else "TS " + ts_info[config_name]["name"]
    plt.title(f"{title}\nN={len(mols)}  MAE={mae*1000:.0f} meV  RMSE={rmse*1000:.0f} meV  max={mx*1000:.0f} meV")
    plt.tight_layout()
    plt.show()

    print(f"{config_name}: N={len(mols)}  MAE={mae*1000:.1f} meV  RMSE={rmse*1000:.1f} meV  max|err|={mx*1000:.1f} meV")

# %%
#Fit configuration energy correction (This cell draws parameters from the first individual configuration cell!)
L = len(Ncoad_energy_dict[coad_name])-1   #which iteration to look at (last = converged)
Ncoads = np.array([0]+[x for x in sorted(Ncoad_energy_dict[coad_name][L][config_name].keys()) if x-1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()])
coverages = Ncoads/MLsize
energies = np.array([get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L,Ncoad,reactant_names=reactant_names)*to_eV if Ncoad > 0 else 0.0 for Ncoad in Ncoads])

params1 = np.polyfit(coverages,energies,1)
params2 = np.polyfit(coverages,energies,2)
params3 = np.polyfit(coverages,energies,3)
params4 = np.polyfit(coverages,energies,4)
params5 = np.polyfit(coverages,energies,5)
params6 = np.polyfit(coverages,energies,6)

vals1 = np.polyval(params1,coverages)
vals2 = np.polyval(params2,coverages)
vals3 = np.polyval(params3,coverages)
vals4 = np.polyval(params4,coverages)
vals5 = np.polyval(params5,coverages)
vals6 = np.polyval(params6,coverages)

plt.scatter(coverages,energies)
plt.plot(coverages,vals1)
plt.plot(coverages,vals2)
plt.plot(coverages,vals3)
plt.plot(coverages,vals4)
plt.plot(coverages,vals5)
plt.plot(coverages,vals6)
plt.legend(["SIDT","linear","2nd order","3rd order","4th order","5th order","6th order"])
plt.ylabel("Species Energy Correction " + config_name + " [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

plt.figure()
poly_maes = [np.mean(np.abs(energies-vals1)),np.mean(np.abs(energies-vals2)),
                     np.mean(np.abs(energies-vals3)),np.mean(np.abs(energies-vals4)),
                    np.mean(np.abs(energies-vals5)),np.mean(np.abs(energies-vals6))]
plt.plot(range(1,7),poly_maes,'o-')

plt.xticks(range(1,7))
plt.ylim(0.0,np.max(poly_maes)+0.1*np.max(poly_maes))
plt.ylabel("Fitting MAE [eV]")
plt.xlabel("Polynomial Order")

#print(f"Polynomial coefficients (highest to lowest order): {params3}") #paramsN corresponds to the Nth order polynomial

# %%
#visualize lowest energy (2D) configurations (in 3D) (This cell draws parameters from the first individual configuration cell!)
#Note that there may be more than one predicted lowest energy configuration at each coverage and this extracts all of them

write_predicted_lowest = True   # if True, write the SIDT predicted lowest-energy configs to a multi-frame xyz

for config_name in config_names:
    iter_configs = len(Ncoad_energy_dict[coad_name])-1 #which iteration to look at (last = converged)

    configs_3D,configs_2D,sidt_Es,sidt_traces = analyze_covdep_lowest_energy(Ncoad_config_dict,iter_configs,config_name,
                                                    coad_name,metal,slab,sites,admol_name_structure_dict,admol_name_path_dict,tree_dict)

    # write the predicted-lowest structures to xyz so they can be opened in external viewers
    if write_predicted_lowest and configs_3D:
        from ase.io import write as _write
        _safe = config_name.replace("/", "_")
        _outpath = f"predicted_lowest_{_safe}.xyz"
        _atoms_list = []
        for _a3, _m, _E in zip(configs_3D, configs_2D, sidt_Es):
            _Ncoad = len(split_adsorbed_structures(_m)) - 1
            if config_name == coad_name:
                _Ncoad += 1
            _a = _a3.copy()
            _a.info["Ncoad"] = _Ncoad
            _a.info["theta"] = round(_Ncoad / MLsize, 4)
            _a.info["sidt_E_eV"] = round(float(_E) * to_eV, 4)
            _atoms_list.append(_a)
        _write(_outpath, _atoms_list)
        print(f"Wrote {len(_atoms_list)} predicted-lowest structures to {_outpath}:")
        for _i, _a in enumerate(_atoms_list):
            print(f"    frame {_i}: Ncoad={_a.info['Ncoad']} theta={_a.info['theta']:.3f} sidt_E={_a.info['sidt_E_eV']} eV")

    view(configs_3D) #see configurations in 3D
    print({i+1:E for i,E in enumerate(sidt_Es)}) #SIDT predicted energies of each configuration
    print({i+1:{(n,i):tree_dict[iter_configs].nodes[n].rule.value for i,n in enumerate(tr)} for i,tr in enumerate(sidt_traces)}) #Final tree nodes and their final rule value associated with each prediction
    print({i+1:m.to_adjacency_list() for i,m in enumerate(configs_2D)}) #see configurations in 2D (adjacency lists)

# %%
#visualize sampled data (calculated 3D geometries) (This cell draws parameters from the first individual configuration cell!)

reactant_names = None #for TSs the energy correction depends on the direction of the reaction and the list of reactant names needs specified here

configs_3D,config_Es,config_E_correction,config_xyzs,config_mols = analyze_covdep_sample_data(config_name,coad_name,
                                                                Ncoad_energy_dict,path,pynta_path,slab,metal,facet,sites,site_adjacency,
                                                                        ad_energy_dict,ts_dict,coadmol_E_dict,reactant_names=reactant_names,
                                                                        admol_name_structure_dict=admol_name_structure_dict)

#view(configs_3D) #Visualize the configurations in 3D
#print({i+1:E for i,E in enumerate(config_Es)}) #Association energies of each configuration
#print({i+1:E for i,E in enumerate(config_E_correction)}) #Energy corrections (energy to move adsorbate/TS (from isolation) and coadsorbates (at coverage) into the configuration)
#print({i+1:config_xyzs[i] for i,E in enumerate(config_Es)}) #location of the xyz files for each configuration
#print({i+1:m.to_adjacency_list() for i,m in enumerate(config_mols)}) #2D adjacency lists for each configuration

# %%
#analyze a reaction 
ts_name = "TS7"
coad_name = "N#[Pt]"
forward = True
if forward:
    reactant_names = ts_info[ts_name]['species_names']
    product_names = ts_info[ts_name]['reverse_names']
else:
    reactant_names = ts_info[ts_name]['reverse_names']
    product_names = ts_info[ts_name]['species_names']

rstr = "+".join(reactant_names) + "=>" + "+".join(product_names)
print(rstr)
reactant_energies = {i: {k : sum([get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,name,coad_name,i,k) if k != 0 else 0.0 for name in reactant_names if name in Ncoad_energy_dict[coad_name][i].keys()]) for k in Ncoad_energy_dict[coad_name][i][ts_name].keys() if all(k in Ncoad_energy_dict[coad_name][i][name] for name in reactant_names if name in Ncoad_energy_dict[coad_name][i].keys())} for i in Ncoad_energy_dict[coad_name].keys()}
product_energies = {i: {k : sum([get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,name,coad_name,i,k) if k != 0 else 0.0 for name in product_names if name in Ncoad_energy_dict[coad_name][i].keys()]) for k in Ncoad_energy_dict[coad_name][i][ts_name].keys() if all(k in Ncoad_energy_dict[coad_name][i][name] for name in product_names if name in Ncoad_energy_dict[coad_name][i].keys())} for i in Ncoad_energy_dict[coad_name].keys()}

# %%
#barrier height (This cell draws parameters from the first reaction cell!)
L = len(Ncoad_energy_dict[coad_name])-1
leg = []
for i in sorted(Ncoad_energy_dict[coad_name].keys()):
    if ts_name not in Ncoad_energy_dict[coad_name][i]:
        continue          # this TS has no data at iteration i yet (partial run)
    leg.append("SIDT Iter "+str(i))
    Ncoads = np.array([Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][i][ts_name].keys()) if Ncoad == 0 or (Ncoad-1 in Ncoad_energy_dict[coad_name][i][coad_name].keys() and Ncoad in Ncoad_energy_dict[coad_name][i][ts_name].keys() and all(Ncoad in Ncoad_energy_dict[coad_name][i][n].keys() for n in reactant_names if n in Ncoad_energy_dict[coad_name][i].keys()))])
    energies = [get_barrier_correction(Ncoad_energy_dict,ts_dict,ts_name,coad_name,i,Ncoad,reactant_names)*to_eV if Ncoad != 0 else 0.0 for Ncoad in Ncoads]
    plt.plot(Ncoads/MLsize,energies,color=cmap(i/L))

plt.legend(leg,loc = "upper left")
plt.ylabel("Barrier Correction " + rstr + " [eV]")
#plt.ylabel("Barrier Correction NH3X => HX + NH2X [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")
#plt.ylim(-2.0,3.0)
#plt.xlim(0,0.65)

# %%
#analyze reaction energy (This cell draws parameters from the first reaction cell!)
L = len(Ncoad_energy_dict[coad_name])-1
leg = []
for i in sorted(Ncoad_energy_dict[coad_name].keys()):
    if ts_name not in Ncoad_energy_dict[coad_name][i]:
        continue          # this TS has no data at iteration i yet (partial run)
    leg.append("SIDT Iter "+str(i))
    Ncoads = np.array([Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][i][ts_name].keys()) if Ncoad == 0 or (Ncoad-1 in Ncoad_energy_dict[coad_name][i][coad_name].keys() and all(Ncoad in Ncoad_energy_dict[coad_name][i][n] for n in reactant_names+product_names if n in Ncoad_energy_dict[coad_name][i].keys()))])
    energies = [get_reaction_energy_correction(Ncoad_energy_dict,ts_dict,ts_name,coad_name,i,Ncoad,reactant_names,product_names)*to_eV if Ncoad != 0 else 0.0 for Ncoad in Ncoads]
    plt.plot(Ncoads/MLsize,energies,color=cmap(i/L))

plt.legend(leg)
plt.ylabel("Reaction Energy Correction " + rstr + " [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")
#plt.ylim(-0.5,3.0)
#plt.xlim(0,0.65)

# %%
#Fit activation barrier correction
L = len(Ncoad_energy_dict[coad_name])-1
Ncoads = np.array([0]+[Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][i][ts_name].keys()) if Ncoad-1 in Ncoad_energy_dict[coad_name][i][coad_name].keys() and all(Ncoad in Ncoad_energy_dict[coad_name][i][n] for n in reactant_names if n in Ncoad_energy_dict[coad_name][i].keys())])
coverages = Ncoads/MLsize
energies = np.array([get_barrier_correction(Ncoad_energy_dict,ts_dict,ts_name,coad_name,i,Ncoad,reactant_names)*to_eV if Ncoad != 0 else 0.0 for Ncoad in Ncoads])


params1 = np.polyfit(coverages,energies,1)
params2 = np.polyfit(coverages,energies,2)
params3 = np.polyfit(coverages,energies,3)
params4 = np.polyfit(coverages,energies,4)
params5 = np.polyfit(coverages,energies,5)
params6 = np.polyfit(coverages,energies,6)

vals1 = np.polyval(params1,coverages)
vals2 = np.polyval(params2,coverages)
vals3 = np.polyval(params3,coverages)
vals4 = np.polyval(params4,coverages)
vals5 = np.polyval(params5,coverages)
vals6 = np.polyval(params6,coverages)

plt.scatter(coverages,energies)
plt.plot(coverages,vals1)
plt.plot(coverages,vals2)
plt.plot(coverages,vals3)
plt.plot(coverages,vals4)
plt.plot(coverages,vals5)
plt.plot(coverages,vals6)
plt.legend(["SIDT","linear","2nd order","3rd order","4th order","5th order","6th order"])
plt.ylabel("Activation Barrier Correction " + rstr + " [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

plt.figure()
poly_maes = [np.mean(np.abs(energies-vals1)),np.mean(np.abs(energies-vals2)),
                     np.mean(np.abs(energies-vals3)),np.mean(np.abs(energies-vals4)),
                    np.mean(np.abs(energies-vals5)),np.mean(np.abs(energies-vals6))]
plt.plot(range(1,7),poly_maes,'o-')

plt.xticks(range(1,7))
plt.ylim(0.0,np.max(poly_maes)+0.1*np.max(poly_maes))
plt.ylabel("Fitting MAE [eV]")
plt.xlabel("Polynomial Order")

#print(f"Polynomial coefficients (highest to lowest order): {params3}") #paramsN corresponds to the Nth order polynomial

# %%
#analyze all adsorbates
coad_name = "N#[Pt]"
L = len(Ncoad_energy_dict[coad_name])-1   #which iteration to look at (last = converged)
leg = []
nice_names_dict = {} #dictionary mapping pynta names to desired names in plot
for config_name in Ncoad_energy_dict[coad_name][L].keys():
    if config_name in ts_info:  # ts_info holds the (possibly compound) TS config keys; skip TSs here
        continue
    if config_name in nice_names_dict.keys():
        leg.append(nice_names_dict[config_name])
    else:
        leg.append(config_name)
        
    Ncoads = np.array([0]+[Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][L][config_name].keys()) if Ncoad-1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()])
    energies = [0.0]+[get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L,Ncoad)*to_eV if Ncoad > 0 else 0.0 for Ncoad in Ncoads if Ncoad-1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()]
    plt.plot(Ncoads/MLsize,energies)
    
for config_name in Ncoad_energy_dict[coad_name][L].keys():
    if config_name not in ts_info:  # only TS configs here
        continue
    if config_name in nice_names_dict.keys():
        leg.append(nice_names_dict[config_name])
    else:
        leg.append(config_name)
    forward = True
    if forward:
        reactant_names = ts_info[config_name]['species_names']
        product_names = ts_info[config_name]['reverse_names']
    else:
        reactant_names = ts_info[config_name]['reverse_names']
        product_names = ts_info[config_name]['species_names']
    Ncoads = np.array([0]+[Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][L][config_name].keys()) if Ncoad-1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()])
    energies = [0.0]+[get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L,Ncoad,reactant_names=reactant_names)*to_eV if Ncoad > 0 else 0.0 for Ncoad in Ncoads if Ncoad-1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()]
    plt.plot(Ncoads/MLsize,energies)
    
plt.legend(leg)
plt.xlim(0,1)
plt.ylabel("Configuration Energy Correction [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

# %%
#analyze all adsorbates convergence
L = len(Ncoad_energy_dict[coad_name])-1
coad_name = "N#[Pt]"
leg = []

nice_names_dict = dict()
for config_name in Ncoad_energy_dict[coad_name][0].keys():
    if config_name in ts_info:  # ts_info holds the (possibly compound) TS config keys; skip TSs here
        continue
    if config_name in nice_names_dict.keys():
        leg.append(nice_names_dict[config_name])
    else:
        leg.append(config_name)
        
    Ncoads = np.array(sorted(Ncoad_energy_dict[coad_name][i][config_name].keys()))
    energies = [(get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L,Ncoad)-get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L-1,Ncoad))*to_eV if Ncoad > 0 else 0.0 for Ncoad in Ncoads if Ncoad+1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()]
    plt.plot(np.array([N for N in Ncoads if N+1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()])/MLsize,energies)
    
for config_name in Ncoad_energy_dict[coad_name][0].keys():
    if config_name not in ts_info:  # only TS configs here
        continue
    if config_name in nice_names_dict.keys():
        leg.append(nice_names_dict[config_name])
    else:
        leg.append(config_name)
    forward = True
    if forward:
        reactant_names = ts_info[config_name]['species_names']
        product_names = ts_info[config_name]['reverse_names']
    else:
        reactant_names = ts_info[config_name]['reverse_names']
        product_names = ts_info[config_name]['species_names']
    Ncoads = np.array(sorted(Ncoad_energy_dict[coad_name][i][config_name].keys()))
    energies = [(get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L,Ncoad,reactant_names=reactant_names)-get_energy_correction_configuration(Ncoad_energy_dict,ts_dict,config_name,coad_name,L-1,Ncoad,reactant_names=reactant_names))*to_eV if Ncoad > 0 else 0.0 for Ncoad in Ncoads if Ncoad+1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()]
    plt.plot(np.array([N for N in Ncoads if N+1 in Ncoad_energy_dict[coad_name][L][coad_name].keys()])/MLsize,energies)
    
plt.legend(leg)
plt.xlim(0,0.65)
plt.ylim(-1,1)
plt.ylabel(r"$E_{L}-E_{L-1}$ [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

# %%
#analyze all barriers
L = len(Ncoad_energy_dict)-1
coad_name = "N#[Pt]"
nice_names_dict = dict()
leg = []
for ts_name in ts_info.keys():  # ts_info keys match Ncoad_energy_dict (compound "TSn_index" for list-valued ts_dict)
    #analyze a reaction 

    forward = True
    if forward:
        reactant_names = ts_info[ts_name]['species_names']
        product_names = ts_info[ts_name]['reverse_names']
    else:
        reactant_names = ts_info[ts_name]['reverse_names']
        product_names = ts_info[ts_name]['species_names']
    
    rstr = "+".join(reactant_names) + "=>" + "+".join(product_names)
    Ncoads = np.array([Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][i][ts_name].keys()) if Ncoad == 0 or (Ncoad-1 in Ncoad_energy_dict[coad_name][i][coad_name].keys() and Ncoad in Ncoad_energy_dict[coad_name][i][ts_name].keys() and all(Ncoad in Ncoad_energy_dict[coad_name][i][n] for n in reactant_names if n in Ncoad_energy_dict[coad_name][i].keys()))])
    barrier_energies = [get_barrier_correction(Ncoad_energy_dict,ts_dict,ts_name,coad_name,L,Ncoad,reactant_names)*to_eV if Ncoad != 0 else 0.0 for Ncoad in Ncoads]
    plt.plot(Ncoads/MLsize,barrier_energies)
    if ts_name in nice_names_dict.keys():
        leg.append(nice_names_dict[ts_name])
    else:
        leg.append(rstr)
plt.legend(leg)
plt.ylabel("Barrier Correction [eV]")
plt.xlim(0,0.65)
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

# %%
#analyze all reaction energies
L = len(Ncoad_energy_dict[coad_name])-1
coad_name = "N#[Pt]"
nice_names_dict = dict()
leg = []
for ts_name in ts_info.keys():  # ts_info keys match Ncoad_energy_dict (compound "TSn_index" for list-valued ts_dict)
    #analyze a reaction 

    forward = True
    if forward:
        reactant_names = ts_info[ts_name]['species_names']
        product_names = ts_info[ts_name]['reverse_names']
    else:
        reactant_names = ts_info[ts_name]['reverse_names']
        product_names = ts_info[ts_name]['species_names']
    
    rstr = "+".join(reactant_names) + "=>" + "+".join(product_names)
    Ncoads = np.array([Ncoad for Ncoad in sorted(Ncoad_energy_dict[coad_name][i][ts_name].keys()) if Ncoad == 0 or (Ncoad-1 in Ncoad_energy_dict[coad_name][i][coad_name].keys() and all(Ncoad in Ncoad_energy_dict[coad_name][i][n] for n in reactant_names+product_names if n in Ncoad_energy_dict[coad_name][i].keys()))])
    energies = [get_reaction_energy_correction(Ncoad_energy_dict,ts_dict,ts_name,coad_name,L,Ncoad,reactant_names,product_names)*to_eV if Ncoad != 0 else 0.0 for Ncoad in Ncoads]
    plt.plot(Ncoads/MLsize,energies)
    if ts_name in nice_names_dict.keys():
        leg.append(nice_names_dict[ts_name])
    else:
        leg.append(rstr)
plt.legend(leg)
plt.xlim(0,0.65)
plt.ylim(-2.0,2.0)
plt.ylabel("Reaction Energy Correction [eV]")
plt.xlabel(r"$\theta_{"+coad_nice_name+r"}$")

# %%
# Visualize a saved MC chain (covdep_mc): writes a multi-frame xyz you open in any viewer.
# Uses only run inputs already defined above -- no MC hyperparameters.
from pynta.coverage_mc import write_mc_chain_xyz

central = "TS0_21"        # central species admol_name; matches Iterations/<i>/mc_chain_<central>_<coad>.json
coad_name = coad_names[0]  # coadsorbate
Ncoad = 2                 # which coverage's chain to render
iteration = None          # None -> latest iteration that HAS this chain for this Ncoad (newest MC may
                          #         be unfinished); set an int to inspect earlier data
open_viewer = False       # default: just write the xyz. True -> also open ASE gui (slow over X on a cluster)

# out_xyz auto-named as mc_chain_<central>_<coad>_N<Ncoad>_iter<i>.xyz (resolved iteration in the name)
out_xyz, frames, energies = write_mc_chain_xyz(path, pynta_path, central, coad_name, Ncoad,
                                               sites, site_adjacency, metal, facet,
                                               iteration=iteration, adsorbate_site_energy_cutoff=None)  # match the run
print(f"wrote {out_xyz}  ({len(frames)} frames); Emin = {min(energies)*to_eV:.4f} eV")

plt.figure(); plt.plot([e*to_eV for e in energies])
plt.xlabel("MC frame"); plt.ylabel("E [eV]"); plt.title(f"{central} N={Ncoad} MC chain"); plt.show()

if open_viewer:
    from ase.visualize import view
    view(frames)

# %%
# Interaction-energy graph of ONE saved MC-chain frame.
# iteration=None -> latest iteration that actually HAS this chain for this Ncoad (the newest
#   iteration's MC may not be finished yet); set iteration=<i> to inspect earlier data.
# out_png=None -> auto-named interaction_<central>_<coad>_N<Ncoad>_iter<i>_frame<f>.png
from pynta.coverage_mc import plot_mc_frame_interaction_graph
fig, ax = plot_mc_frame_interaction_graph(
    path, pynta_path, central="TS0_21", coadname="[O]=[Pt]", Ncoad=5,
    frame=-1, sites=sites, site_adjacency=site_adjacency, metal=metal, facet=facet,
    iteration=None, out_png=None)

# %%
# Pairwise-interaction maps from the RAW pairs data (path/pairs), one image per central-adsorbate site.
# Unlike the SIDT interaction graph above, this reads each optimized central+ONE-coadsorbate config and
# takes its interaction energy straight from that pair's datum.json (the value the covdep sampler
# already computed and the model is trained on: ZPE-corrected coadsorption dE with the per-adsorbate
# baseline subtracted). Configs are grouped by the central's binding site; every central atom is
# overlaid (the central "pile", element-colored) and each coadsorbate is an element-colored dot +
# lettered dE label. Both adsorbate and TS centrals are included. No translations/rotations.
#   add_atom_correction=True (needs coadmol_E_dict) shows the physical dE = E_coad - E_central - E_coad.
#   centrals=... restricts to one/some central species (folder prefix / first token of the title,
#     e.g. "[O]=[Pt]", "[OH][Pt]", "TS0_52"); None = all. Every image is framed to the same slab extent.
from pynta.coveragedependence import plot_pairs_interaction_maps

central_filter = None   # e.g. "[O]=[Pt]" for just O-centered maps, or ["[O]=[Pt]","TS0_52"]; None -> all

for coad_name in coad_names:
    results = plot_pairs_interaction_maps(
        path, pynta_path, coad_name, ad_energy_dict, slab, sites, site_adjacency, metal, facet,
        out_dir="pairs_interaction_maps",   # None -> don't write PNGs, just show
        unit="meV",                          # meV / eV / kJ/mol for the labels
        centrals=central_filter,             # which central species to plot (None -> all)
        min_configs=1,                       # skip central sites with fewer than this many coadsorptions
        min_abs=None,                        # hide labels below this |dE| (in `unit`); None -> show all
        coadmol_E_dict=coadmol_E_dict,       # only used when add_atom_correction=True
        add_atom_correction=False,           # True -> physical dE (baseline added back)
        verbose=True)                        # prints skip-reason counts if a coad yields 0 groups
    print(f"{coad_name}: {len(results)} central-site maps")
    for (central_label, site_inds), fig, ax in results:
        plt.show()
